# %% [markdown]
# # 00 - Print cat
#
# This notebooks is used to verify that the environment is working correctly.
# Run all cells and check that you see a cat at the end.

# %%
# %pip install numpy --quiet
# %pip install matplotlib --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
 
# read the image
img = cv2.imread('../cat.jpg')
# convert to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plot the image
plt.imshow(img)
